# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Vanilla GAN

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from models.gan import Generator, Discriminator, train_gan
from data.toy_dataset import get_25gaussians_grid_dataloader

# Hyperparameters
latent_dim = 64  # Dimensionality of the latent space
z_dim = latent_dim
image_size = 28 * 28  # Grid size for images
hidden_dim = 256  # Hidden dimension size for both Generator and Discriminator
batch_size = 128  # Batch size for training
epochs = 50  # Number of training epochs
learning_rate = 2e-4  # Learning rate for optimizers
device = "cuda" if torch.cuda.is_available() else "cpu"

# Instantiate models
gen = Generator(latent_dim=latent_dim, out_dim=image_size, hidden_dim=hidden_dim).to(device)
disc = Discriminator(inp_dim=image_size, hidden_dim=hidden_dim).to(device)

# Load dataset
dataloader = get_25gaussians_grid_dataloader(batch_size=batch_size, grid_size=28, num_samples=100000)

# Define loss function
loss_func = nn.BCEWithLogitsLoss()  # Binary Cross-Entropy Loss with logits

# Define optimizers
gen_opt = optim.Adam(gen.parameters(), lr=learning_rate, betas=(0.5, 0.999))
disc_opt = optim.Adam(disc.parameters(), lr=learning_rate, betas=(0.5, 0.999))

# Train the GAN
results = train_gan(
    gen=gen,
    disc=disc,
    dataloader=dataloader,
    gen_opt=gen_opt,
    disc_opt=disc_opt,
    loss_func=loss_func,
    z_dim=z_dim,
    epochs=epochs,
    device=device,
    info_iter=10000  # Display stats and images every 10000 iterations
)

# # Visualization of losses (optional)
# import matplotlib.pyplot as plt

# plt.plot(results["iterations"], results["mean_gen_loss"], label="Generator Loss")
# plt.plot(results["iterations"], results["mean_disc_loss"], label="Discriminator Loss")
# plt.xlabel("Iterations")
# plt.ylabel("Loss")
# plt.title("GAN Training Losses")
# plt.legend()
# plt.show()
# Out:
# Epoch 1/50
# Training Epoch 1: 100%|██████████| 782/782 [00:09<00:00, 81.55it/s]
# Epoch 2/50
# Training Epoch 2: 100%|██████████| 782/782 [00:09<00:00, 84.32it/s]
# Epoch 3/50
# Training Epoch 3: 100%|██████████| 782/782 [00:09<00:00, 86.43it/s]
# Epoch 4/50
# Training Epoch 4: 100%|██████████| 782/782 [00:09<00:00, 84.43it/s]
# Epoch 5/50
# Training Epoch 5: 100%|██████████| 782/782 [00:08<00:00, 87.52it/s]
# Epoch 6/50
# Training Epoch 6: 100%|██████████| 782/782 [00:09<00:00, 82.82it/s]
# Epoch 7/50
# Training Epoch 7: 100%|██████████| 782/782 [00:09<00:00, 82.38it/s]
# Epoch 8/50
# Training Epoch 8: 100%|██████████| 782/782 [00:09<00:00, 84.33it/s]
# Epoch 9/50
# Training Epoch 9: 100%|██████████| 782/782 [00:08<00:00, 86.97it/s]
# Epoch 10/50
# Training Epoch 10: 100%|██████████| 782/782 [00:09<00:00, 84.57it/s]
# Epoch 11/50
# Training Epoch 11: 100%|██████████| 782/782 [00:09<00:00, 85.15it/s]
# Epoch 12/50
# Training Epoch 12: 100%|██████████| 782/782 [00:09<00:00, 81.76it/s]
# Epoch 13/50
# Training Epoch 13:  79%|███████▊  | 615/782 [00:07<00:01, 84.64it/s]
# Step 10000, Generator Loss: 18.1724, Discriminator Loss: 0.0012
# Training Epoch 13: 100%|██████████| 782/782 [00:09<00:00, 80.62it/s]
# Epoch 14/50
# Training Epoch 14: 100%|██████████| 782/782 [00:08<00:00, 87.15it/s]
# Epoch 15/50
# Training Epoch 15: 100%|██████████| 782/782 [00:09<00:00, 85.59it/s]
# Epoch 16/50
# Epoch 47/50
# Training Epoch 47: 100%|██████████| 782/782 [00:09<00:00, 80.97it/s]
# Epoch 48/50
# Training Epoch 48: 100%|██████████| 782/782 [00:09<00:00, 81.03it/s]
# Epoch 49/50
# Training Epoch 49: 100%|██████████| 782/782 [00:09<00:00, 83.30it/s]
# Epoch 50/50
# Training Epoch 50: 100%|██████████| 782/782 [00:09<00:00, 83.72it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 49
#      46 # Visualization of losses (optional)
#      47 import matplotlib.pyplot as plt
# ---> 49 plt.plot(results["iterations"], results["mean_gen_loss"], label="Generator Loss")
#      50 plt.plot(results["iterations"], results["mean_disc_loss"], label="Discriminator Loss")
#      51 plt.xlabel("Iterations")
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/matplotlib/pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/matplotlib/axes/_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (39100,) and (3,)

# %% [markdown]
# ### DDPM

# %%
import torch
from torch.optim import Adam
from tqdm import tqdm

from models.ddpm_unet import train_unet, UNet, NoiseScheduler
from data.toy_dataset import get_25gaussians_grid_dataloader


def initialize_unet_and_scheduler():
    # Initialize UNet model with the required arguments
    model = UNet(image_channels=1,  # 1 for grayscale (25-Gaussians)
                 n_channels=64,
                 ch_mults=(1, 2, 2, 4),  # Example configuration
                 is_attn=(False, False, True, True),  # Attention at some resolutions
                 n_blocks=2)  # 2 blocks at each resolution

    # Initialize NoiseScheduler with the number of timesteps
    noise_scheduler = NoiseScheduler(num_train_timesteps=1000)

    return model, noise_scheduler

# Training Configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
epochs = 10
batch_size = 32
learning_rate = 1e-4
save_path = "./unet_model.pth"

# Initialize components
model, noise_scheduler = initialize_unet_and_scheduler()
optimizer = Adam(model.parameters(), lr=learning_rate)
dataloader = get_25gaussians_grid_dataloader(batch_size=batch_size, grid_size=32)

# Train the U-Net model
train_unet(
    model=model,
    dataloader=dataloader,
    noise_scheduler=noise_scheduler,
    optimizer=optimizer,
    device=device,
    epochs=epochs,
    save_path=save_path,
)
# Out:
# Epoch 1/10:   0%|          | 0/3125 [00:00<?, ?it/s]/home/leo/anaconda3/envs/igm/lib/python3.9/site-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([32, 32, 32])) that is different to the input size (torch.Size([32, 1, 32, 32])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/10: 100%|██████████| 3125/3125 [15:02<00:00,  3.46it/s, Loss=0.995]
# Epoch 1 completed. Average Loss: 0.999470
# Model saved at ./unet_model.pth
# Epoch 2/10: 100%|██████████| 3125/3125 [15:01<00:00,  3.47it/s, Loss=0.998]
# Epoch 2 completed. Average Loss: 0.999139
# Model saved at ./unet_model.pth
# Epoch 3/10: 100%|██████████| 3125/3125 [14:58<00:00,  3.48it/s, Loss=0.987]
# Epoch 3 completed. Average Loss: 0.999166
# Model saved at ./unet_model.pth
# Epoch 4/10: 100%|██████████| 3125/3125 [14:54<00:00,  3.50it/s, Loss=1]
# Epoch 4 completed. Average Loss: 0.999105
# Model saved at ./unet_model.pth
# Epoch 5/10: 100%|██████████| 3125/3125 [14:54<00:00,  3.49it/s, Loss=0.993]
# Epoch 5 completed. Average Loss: 0.998967
# Model saved at ./unet_model.pth
# Epoch 6/10: 100%|██████████| 3125/3125 [14:54<00:00,  3.49it/s, Loss=1]
# Epoch 6 completed. Average Loss: 0.999145
# Model saved at ./unet_model.pth
# Epoch 7/10: 100%|██████████| 3125/3125 [14:53<00:00,  3.50it/s, Loss=0.996]
# Epoch 7 completed. Average Loss: 0.999053
# Model saved at ./unet_model.pth
# Epoch 8/10: 100%|██████████| 3125/3125 [14:53<00:00,  3.50it/s, Loss=1.01]
# Epoch 8 completed. Average Loss: 0.998899
# Model saved at ./unet_model.pth
# Epoch 9/10: 100%|██████████| 3125/3125 [14:53<00:00,  3.50it/s, Loss=1.01]
# Epoch 9 completed. Average Loss: 0.999122
# Model saved at ./unet_model.pth
# Epoch 10/10: 100%|██████████| 3125/3125 [14:53<00:00,  3.50it/s, Loss=1.01]
# Epoch 10 completed. Average Loss: 0.999115
# Model saved at ./unet_model.pth

# %%
def sample_images(model, noise_scheduler, num_images=10, image_size=28, device="cuda"):
    """
    Generate and return sampled images using the trained U-Net model and DDPM process.

    Args:
        model (torch.nn.Module): Trained U-Net model.
        noise_scheduler (NoiseScheduler): Noise scheduler for DDPM.
        num_images (int): Number of images to generate.
        image_size (int): Size of the square images (e.g., 28x28).
        device (str): Device to use ('cuda' or 'cpu').

    Returns:
        List of generated images as numpy arrays.
    """
    model.eval()
    model.to(device)

    # Start with pure Gaussian noise
    images = torch.randn(num_images, 1, image_size, image_size, device=device)

    # Reverse diffusion process
    for t in reversed(range(noise_scheduler.num_train_timesteps)):
        t_tensor = torch.tensor([t] * num_images, device=device).long()
        alpha_cumprod = noise_scheduler.alpha_cumprod[t]
        sqrt_alpha_cumprod = torch.sqrt(alpha_cumprod)
        sqrt_one_minus_alpha_cumprod = torch.sqrt(1 - alpha_cumprod)

        # Predict the noise using the U-Net
        predicted_noise = model(images, t_tensor)

        # Estimate the denoised image
        if t > 0:
            alpha_cumprod_prev = noise_scheduler.alpha_cumprod[t - 1]
            beta_t = 1 - alpha_cumprod / alpha_cumprod_prev
            noise = torch.randn_like(images) if t > 1 else torch.zeros_like(images)
            images = (
                sqrt_alpha_cumprod * (images - predicted_noise) / sqrt_one_minus_alpha_cumprod
                + torch.sqrt(beta_t) * noise
            )
        else:
            # Final step: directly use the predicted image
            images = sqrt_alpha_cumprod * (images - predicted_noise) / sqrt_one_minus_alpha_cumprod

    return images.detach().cpu().numpy()


import matplotlib.pyplot as plt

def plot_generated_images(images, num_images=10):
    """
    Plot the generated images.

    Args:
        images (numpy.ndarray): Generated images as a numpy array.
        num_images (int): Number of images to plot.
    """
    fig, axes = plt.subplots(1, num_images, figsize=(num_images * 2, 2))
    for i in range(num_images):
        ax = axes[i]
        ax.imshow(images[i, 0], cmap="gray")  # Single-channel image
        ax.axis("off")
    plt.tight_layout()
    plt.show()

# Example usage
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = "cpu"
generated_images = sample_images(model, noise_scheduler, num_images=10, image_size=32, device=device)
plot_generated_images(generated_images, num_images=10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 68
#      65 # Example usage
#      66 # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      67 device = "cpu"
# ---> 68 generated_images = sample_images(model, noise_scheduler, num_images=10, image_size=32, device=device)
#      69 plot_generated_images(generated_images, num_images=10)
#
# Cell In[4], line 16, in sample_images(model, noise_scheduler, num_images, image_size, device)
#       2 """
#       3 Generate and return sampled images using the trained U-Net model and DDPM process.
#       4
#    (...)
#      13     List of generated images as numpy arrays.
#      14 """
#      15 model.eval()
# ---> 16 model.to(device)
#      18 # Start with pure Gaussian noise
#      19 images = torch.randn(num_images, 1, image_size, image_size, device=device)
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/torch/nn/modules/module.py:1340, in Module.to(self, *args, **kwargs)
#    1337         else:
#    1338             raise
# -> 1340 return self._apply(convert)
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/torch/nn/modules/module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/torch/nn/modules/module.py:927, in Module._apply(self, fn, recurse)
#     923 # Tensors stored in modules are graph leaves, and we don't want to
#     924 # track autograd history of `param_applied`, so we have to use
#     925 # `with torch.no_grad():`
#     926 with torch.no_grad():
# --> 927     param_applied = fn(param)
#     928 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     930 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/anaconda3/envs/igm/lib/python3.9/site-packages/torch/nn/modules/module.py:1326, in Module.to.<locals>.convert(t)
#    1319     if convert_to_format is not None and t.dim() in (4, 5):
#    1320         return t.to(
#    1321             device,
#    1322             dtype if t.is_floating_point() or t.is_complex() else None,
#    1323             non_blocking,
#    1324             memory_format=convert_to_format,
#    1325         )
# -> 1326     return t.to(
#    1327         device,
#    1328         dtype if t.is_floating_point() or t.is_complex() else None,
#    1329         non_blocking,
#    1330     )
#    1331 except NotImplementedError as e:
#    1332     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# RuntimeError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
